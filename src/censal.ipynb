# %%
import geopandas as gpd

secciones = gpd.read_file("geodata/SECC_CE_20250101.shp")

# %%
print(secciones.crs)
print(secciones.columns)
secciones.head()
# Out:
# EPSG:25830
# Index(['CUSEC', 'CUMUN', 'CSEC', 'CDIS', 'CMUN', 'CPRO', 'CCA', 'CUDIS',
#        'CLAU2', 'NPRO', 'NCA', 'CNUT0', 'CNUT1', 'CNUT2', 'CNUT3', 'NMUN',
#        'geometry'],
#       dtype='str')
#         CUSEC  CUMUN CSEC CDIS CMUN CPRO CCA    CUDIS  CLAU2         NPRO  \
# 0  0100101001  01001  001   01  001   01  16  0100101  01001  Araba/Álava
# 1  0100101002  01001  002   01  001   01  16  0100101  01001  Araba/Álava
# 2  0100201001  01002  001   01  002   01  16  0100201  01002  Araba/Álava
# 3  0100201002  01002  002   01  002   01  16  0100201  01002  Araba/Álava
# 4  0100201003  01002  003   01  002   01  16  0100201  01002  Araba/Álava
#
#           NCA CNUT0 CNUT1 CNUT2 CNUT3              NMUN  \
# 0  País Vasco    ES     2     1     1  Alegría-Dulantzi
# 1  País Vasco    ES     2     1     1  Alegría-Dulantzi
# 2  País Vasco    ES     2     1     1           Amurrio
# 3  País Vasco    ES     2     1     1           Amurrio
# ...

# %%
secciones = secciones.to_crs(epsg=25831)
